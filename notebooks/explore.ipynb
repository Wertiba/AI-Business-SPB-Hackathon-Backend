# %% [markdown]
# # NeuroICE — Exploration & RMS Baseline

# %%
import pandas as pd
from pathlib import Path

DATA = Path('../data')
train_m = pd.read_csv(DATA / 'train_manifest.csv')
test_m = pd.read_csv(DATA / 'test_public_manifest.csv')
print('train chunks:', len(train_m), 'train sessions:', train_m['source_session_id'].nunique())
print('test chunks: ', len(test_m), 'test sessions: ', test_m['source_session_id'].nunique())
train_m.head()

# %%
train_m.groupby('source_session_id').size().describe()

# %%
import sys
sys.path.insert(0, '../../../Downloads/neuroice (Copy 1)')
from solution import PredictionModel

model = PredictionModel()
preds = model.predict(DATA / 'test_public', DATA / 'test_public_manifest.csv')
preds.to_csv(DATA / 'predictions.csv', index=False)
preds['anomaly_score'].describe()

# %%
preds['anomaly_score'].hist(bins=40)
